# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langchain.checkpoint.memory import InMemorySaver
from lanchain_core.messages import HumanMessage, SystemMessage

agent=create_agent(
    model="gpt-4o-mini"
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model="gpt-4o-mini",
            trigger=("messages", 10),
            keep=("messages", 4)
        )
    ]
)
# Out:
#   Cell In[2], line 7
#     model="gpt-4o-mini"
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
config={"configurable": {"thread_id":"test-1"}}
# Out:
#   Cell In[3], line 1
#     config=("configurable": {"thread_id":"test-1"})
#                           ^
# SyntaxError: invalid syntax

# %%
questions=[
    "Whats is 2+2",
    "Whats is 10*5",
    "Whats is 100/4",
    "What is 15-7",
    "What is 3*3",
    "What is 4*4",
]
for q in questions:
    response=agent.invoke({"messages": [HumanMessage(content=q)]}, config)
    print(f"Messages: {response}")
    print(f"Messages: {len(response['messages'])}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       6     "What is 3*3",
#       7     "What is 4*4",
#       8 ]
#       9 for q in questions:
# ---> 10     response=agent.invoke({"messages": [HumanMessage(content=q)]}, config)
#      11     print(f"Messages: {response}")
#      12     print(f"Messages: {len(response['messages'])}")
#
# NameError: name 'agent' is not defined

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langchain.checkpoint.memory import InMemorySaver
from lanchain_core.messages import HumanMessage, SystemMessage
from langchain_core.tools import tool
def search_hotels(city: str)->str:
    """Search hotels - returns long response to use more tokens."""
    return f"""Hotels in {city}:
    1. Grand Hotel - 5 star, $350/night, spa, pool, gym
    2. City Inn - 4 star, $180/night, business center
    3. Budget Stay - 3 star, $75/night, free wifi"""

agent=create_agent(
    model="gpt-4o-mini",
    tools=[search_hotels],
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware:(
            model="gpt-4o-mini",
            trigger=("tokens", 550),
            keep=("tokens", 200)
        ),
    ]
)

config={"configurable":{"thread_id":"test-1"}}

def count_tokens(messages):
    total_chars=sum(len(str(m.content)) for m in messages)
    return total_chars//4
# Out:
#   Cell In[1], line 18
#     SummarizationMiddleware:(
#                            ^
# SyntaxError: invalid syntax

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langchain.agents.memory import InMemorySaver

def read_email_tool(email_id: str)->str:
    """Mock function to read an email by its ID,"""
    return f"Email content for ID:{email_id}"

def send_email_tool(recipient: str, subject: str, body: str)-> str:
    """Mock function to read an email."""
    return f"Email sent to {recipient} with subject '{subject}'"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 from langchain.agents import create_agent
#       2 from langchain.agents.middleware import HumanInTheLoopMiddleware
# ----> 3 from langchain.agents.memory import InMemorySaver
#       4
#       5 def read_email_tool(email_id: str)->str:
#       6     """Mock function to read an email by its ID,"""
#
# ModuleNotFoundError: No module named 'langchain.agents.memory'

# %%
agent=create_agent(
    model="gpt-4o",
    tools=[read_email_tool, send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_emaio_tool":{
                    "allowed_decisions":["approve", "edit","reject"]
                },
                "read_email_tool": False,
            }
        )
    ]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 agent=create_agent(
#       2     model="gpt-4o",
# ----> 3     tools=[read_email_tool, send_email_tool],
#       4     checkpointer=InMemorySaver(),
#       5     middleware=[
#       6         HumanInTheLoopMiddleware(
#
# NameError: name 'read_email_tool' is not defined

# %%
from langgraph.store.base import Result
config={"configurable":{"thread_id":"test-approve"}}

result=agent.invoke(
    {"messages":[HumanMessage(content="Send email to john@test.com with the subject 'Hello' and body 'How are you?'")]},
    config=config
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 from langgraph.store.base import Result
#       2 config={"configurable":{"thread_id":"test-approve"}}
#       3
# ----> 4 result=agent.invoke(
#       5     {"messages":[HumanMessage(content="Send email to john@test.com with the subject 'Hello' and body 'How are you?'")]},
#       6     config=config
#       7 )
#
# NameError: name 'agent' is not defined

# %%
from langgraph.types import Command
if "__interrupt__" in result:
    print("Paused! Approving...")

    result=agent.invoke(
        Command(
            resume={
                "decisions":[
                    {"type": "approve"}
                ]
            }
        ),
        config=config
    )

    print(f"Result: {result['messages'][-1].content}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 from langgraph.types import Command
# ----> 2 if "__interrupt__" in result:
#       3     print("Paused! Approving...")
#       4
#       5     result=agent.invoke(
#
# NameError: name 'result' is not defined

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
config={"configurable": {"thread_id": "test-reject"}}

result=agent.invoke(
    {"messages": [HumanMessage(content="Send email to john@test.com with the subject 'Hello' and body 'How are you?'")]},
config=config
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 config={"configurable": {"thread_id": "test-reject"}}
#       2
# ----> 3 result=agent.invoke(
#       4     {"messages": [HumanMessage(content="Send email to john@test.com with the subject 'Hello' and body 'How are you?'")]},
#       5 config=config
#       6 )
#
# NameError: name 'agent' is not defined

# %%
from langgraph.types import Command
if "__interrupt__" in result:
    print("Paused! Approving...")

    result=agent.invoke(
        Command(
            resume={
                "decisions":[
                    {"type": "approve"}
                ]
            }
        ),
        config=config
    )

    print(f"Result: {result['messages'][-1].content}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from langgraph.types import Command
# ----> 2 if "__interrupt__" in result:
#       3     print("Paused! Approving...")
#       4
#       5     result=agent.invoke(
#
# NameError: name 'result' is not defined

# %%
if="__interrupt__" in result:
    print("Paused! Editing...")

    result=agent.invoke(
        Command(
            resume={
            "decisions": [
                {
                    "type":"edit",
                    "edited_action":{
                        "name":"send_email_tool",
                        "args":{
                            "recipient":"correct@gmail.com",
                            "subject":"Corrected_Subject",
                            "body":"THis was editing by human before sending"
                        }
                    }
                }
            ]
            }
        ),
        config=config
    )
