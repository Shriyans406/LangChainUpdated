# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
model=init_chat_model("groq:qwen/qwen3-32b")
model
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.6.2', 'langchain': '1.4.0'}}, profile={'name': 'Qwen3 32B', 'release_date': '2024-12-23', 'last_updated': '2024-12-23', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 40960, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x0000021E2D440050>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000021E2D440D70>, model_name='qwen/qwen3-32b', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from pydantic import BaseModel, Field

class Movie(BaseModel):
    title:str=Field(description="Title of the movie")
    year:int=Field(description="The year the movie was released")
    director:str=Field("The director of the movie")
    rating:float=Field(description="The movies rating out of 10")

# %%
model_with_structure=model.with_structured_output(Movie)
model_with_structure
# Out:
# _ChatModelBinding(bound=ChatGroq(metadata={'lc_versions': {'langchain-core': '1.6.2', 'langchain': '1.4.0'}}, profile={'name': 'Qwen3 32B', 'release_date': '2024-12-23', 'last_updated': '2024-12-23', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 40960, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x0000021E2D440050>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000021E2D440D70>, model_name='qwen/qwen3-32b', model_kwargs={}, groq_api_key=SecretStr('**********')), kwargs={'tools': [{'type': 'function', 'function': {'name': 'Movie', 'description': '', 'parameters': {'properties': {'title': {'description': 'Title of the movie', 'type': 'string'},
# ...

# %%
model.invoke("Provide detaila about the movie Inception")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model.invoke("Provide detaila about the movie Inception")
#
# File ~\OneDrive\Desktop\LangChainAI\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)    481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
#     489                 [self._convert_input(input)],
#     490                 stop=stop,
#     491                 callbacks=config.get("callbacks"),
#     492                 tags=config.get("tags"),
# ...

# %%
response=model_with_structure.invoke("Provide details about the movie Inception")
response
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 response=model_with_structure.invoke("Provide details about the movie Inception")
#
# File ~\OneDrive\Desktop\LangChainAI\.venv\Lib\site-packages\langchain_core\runnables\base.py:3454, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3452 with set_config_context(config) as context:
#    3453     if i == 0:
# -> 3454         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3455     else:
#    3456         input_ = context.run(step.invoke, input_, config)
#
# File ~\OneDrive\Desktop\LangChainAI\.venv\Lib\site-packages\langchain_core\runnables\base.py:6014, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    6007 @override
#    6008 def invoke(
#    6009     self,
#    (...)   6012     **kwargs: Any | None,
#    6013 ) -> Output:
# ...

# %%
from langsmith.evaluation._runner import _include_attachments
from pydantic import BaseModel, Field

class Movie(BaseModel):
    title:str=Field(..., description="Title of the movie")
    year:int=Field(..., description="The year the movie was released")
    director:str=Field(..., "The director of the movie")
    rating:float=Field(..., description="The movies rating out of 10")

model_with_structure=model_with_structure_output(Movie, _include_raw=True)
respose=model_with_structure.invoke("Provide details about the movie Inception")
response
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 from langsmith.evaluation._runner import _include_attachments
#       2 from pydantic import BaseModel, Field
#       3
# ----> 4 class Movie(BaseModel):
#       5     title:str=Field(..., description="Title of the movie")
#       6     year:int=Field(..., description="The year the movie was released")
#       7     director:str=Field(..., "The director of the movie")
#
# Cell In[6], line 7, in Movie()
#       4 class Movie(BaseModel):
#       5     title:str=Field(..., description="Title of the movie")
#       6     year:int=Field(..., description="The year the movie was released")
# ----> 7     director:str=Field(..., "The director of the movie")
#       8     rating:float=Field(..., description="The movies rating out of 10")
#
# ...

# %%
from pydantic import BaseModel, Field
class Actor(BaseModel):
    name: str
    role: str

class MOvieDetail(BaseModel):
    title: str
    year: int
    cart: list[Actor]
    genres: list[str]
    budget: float | None=Field(None, description="Budget is million USD")
    
model_with_structure=model_with_structured_output(MovieDetails)

response=model_with_structure.invoke("Provide detaisl about movie Inception")
response
